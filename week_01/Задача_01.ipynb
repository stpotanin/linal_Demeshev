# %% [markdown]
# [git](https://github.com/bdemeshev/coursera_linal/blob/master/week_01/problems/quiz_questions.yml)
#
# # Задача 01

# %% [markdown]
# ## Вариант 1
# Даны два вектора $a=(7,8,9), b=(6,3,5)$. Найдите $\|a-b\|$. Округлите полученный ответ с точностью до двух знаков после запятой.

# %% [markdown]
# ## Решение

# %% [markdown]
# $\|a-b\| = \sqrt{1^2 + 5^2 + 4^2} = \sqrt{42} $
#
# [Расчет евклидова расстояния с помощью NumPy](https://habr.com/ru/articles/579914/https://habr.com/ru/articles/579914/https://habr.com/ru/articles/579914/)
#
# * 1-й способ
# Функция `np.linalg.norm()` представляет математическую норму. По сути, нормой вектора является его длина. Эта длина не обязательно должна быть евклидовым расстоянием, а может быть и другими расстояниями. Евклидово расстояние-это норма `L2` вектора (иногда известная как евклидова норма), и по умолчанию функция `norm()` использует `L2` - параметр `ord` имеет значение `2`.
#
# * 2-й способ.
# С помощью NumPy мы можем использовать функцию np.dot(), передавая два вектора.
#
# Если мы вычислим точечное произведение разницы между обеими точками с той же разницей - мы получим число, которое находится в зависимости от евклидова расстояния между этими двумя векторами. Извлечение квадратного корня из этого числа дает нам расстояние, которое мы ищем:

# %%
#@title 1-й способ

import numpy as np

a = [7, 8, 9]
b = [6, 3, 5]

# np.linalg.norm(np.array(a) - np.array(b), ord=1)    # Манхэттен
np.linalg.norm(np.array(a) - np.array(b))

# (6.4, 6.5] true
# Out:
# 6.48074069840786

# %%
#@title 2-й способ решения, через скалярное произведение
np.dot(np.array(a) - np.array(b), np.array(a) - np.array(b)) ** .5
# Out:
# 6.48074069840786

# %% [markdown]
# ## Вариант 2
# Даны два вектора $a=(7,8,9), b=(6,3,5)$. Найдите  $\langle a, b \rangle$.

# %% [markdown]
# ## Решение

# %% [markdown]
# $\langle a, b \rangle = 42+24+ 45 = 111 $.

# %%
#@title Код
aa = [7, 8, 9]
bb = [6, 3, 5]

np.dot(np.array(aa), np.array(bb))
#
# Out:
# 111

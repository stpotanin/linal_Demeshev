# %% [markdown]
# [git](https://github.com/bdemeshev/coursera_linal/blob/master/week_01/problems/quiz_questions.yml)
#
# # Задача 1

# %% [markdown]
# ## Вариант 1
# Найдите $t$, такое, что $\langle t,1,3 \rangle \perp \langle 2,7,8 \rangle$.

# %% [markdown]
# ## Решение

# %% [markdown]
# $ 2t + 1\cdot7 + 3\cdot 8 = 0 $
#
# $ t = -15.5 $

# %%
#@title Ответ
(1 * 7 + 3 * 8) / (-2)
# @markdown $t = -15.5$
# value:    -15.5   true
# Out:
# -15.5

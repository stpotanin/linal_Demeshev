# %% [markdown]
# [git](https://github.com/bdemeshev/coursera_linal/blob/master/week_01/problems/quiz_questions.yml)
#
# # Задача 07

# %% [markdown]
# ## Вариант 1
# Пусть $A: \begin{pmatrix}v_{1} \\v_{2}\end{pmatrix} \to \begin{pmatrix}- v_{2} \\v_{1} \end{pmatrix}, $ $x = \begin{pmatrix}1 \\2\end{pmatrix}.$ Найдите $ v = A^{21} x, w = A^{15} x $. В ответе укажите $\langle w, v \rangle$.

# %% [markdown]
# ## Решение

# %% [markdown]
# $v = \begin{pmatrix}-2 \\1\end{pmatrix};$ $w = \begin{pmatrix}2 \\-1\end{pmatrix};$ $\langle w, v \rangle = -5$

# %%
#@title Ответ
# value:-5  true

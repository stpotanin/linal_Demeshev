# %% [markdown]
# [git](https://github.com/bdemeshev/coursera_linal/blob/master/week_01/problems/quiz_questions.yml)
#
# # Задача 01

# %% [markdown]
# ## Вариант 1
# Пусть $A: \begin{pmatrix}v_{1} \\v_{2}\end{pmatrix} \to \begin{pmatrix}v_{2} \\v_{1} \end{pmatrix}, $ $v = \begin{pmatrix}1 \\2\end{pmatrix}.$ Найдите $ w = A^{21} v $. В ответе укажите $\langle w, v \rangle$.

# %% [markdown]
# ## Решение

# %% [markdown]
# $w = \begin{pmatrix}2 \\1\end{pmatrix};$ $\langle w, v \rangle = 4$

# %%
#@title Ответ
# value:4 true

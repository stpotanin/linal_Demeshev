# %% [markdown]
# [git](https://github.com/bdemeshev/coursera_linal/blob/master/week_01/problems/quiz_questions.yml)
#
# # Задача 08

# %% [markdown]
# ## Вариант 1
# Пусть для $\phi: \mathbb{R}^{3} \rightarrow \mathbb{R}$ верно $\phi(1,1,0)=-1, \quad \phi(-1,1,1)=1, \quad \phi(1,-1,-1)=1$. Выберите верное утверждение.
#
# * $\phi$ является линейной функцией.
# * $\phi$ может быть линейной функцией.
# * $\phi$ не может быть линейной функцией.

# %% [markdown]
# ## Решение

# %% [markdown]
# * $\phi$ является линейной функцией. false
# * $\phi$ может быть линейной функцией. false
# * $\phi$ не может быть линейной функцией. true

# %%
#@title Ответ

# * $\phi$ не может быть линейной функцией. true
